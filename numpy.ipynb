# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy.stats import skew,kurtosis

# %%
#chi squared test 

chi_sq_array=random.chisquare(df=2,size=400)

# %%
sns.displot(chi_sq_array,kind="kde")
# Out:
# c:\Users\Ashutosh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
skewness =skew(chi_sqr_array,axis=0)

# %%
skewness
# Out:
# 2.1252341530492336

# %%
kurtosiss =kurtosis(chi_sqr_array,axis=0)

# %%
kurtosiss
# Out:
# 6.46473247376437

# %%
normal_array=random.normal(size=400)

# %%
skewness_norm=skew(normal_array)

# %%
skewness_norm
# Out:
# 0.19678115567480045

# %%
sns.distplot(normal_array,hist=False)
# Out:
# C:\Users\Ashutosh\AppData\Local\Temp\ipykernel_5104\2431493121.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_array,hist=False)
# <Axes: ylabel='Density'>

# %%
kurtosis_norm=kurtosis(normal_array)

# %%
kurtosis_norm
# Out:
# -0.07962028719955194

# %%
import pandas as pd

# %%
df=pd.read_csv()
